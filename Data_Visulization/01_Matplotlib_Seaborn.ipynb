# %% [markdown]
# ## What is Data Visualization?
# - Data visualization is the graphical representation of information and data.
# - By using visual elements like charts, graphs, and maps, data visualization tools provide an accessible way to see and understand trends, outliers, and patterns in data.

# %% [markdown]
# ## Important Libraries for Data Visualization in Python
# - Matplotlib: Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# - Seaborn: Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# - Plotly: Plotly is a Python graphing library that makes interactive, publication-quality graphs online.
# - Bokeh: Bokeh is an interactive visualization library that targets modern web browsers for presentation.
# - Altair: Altair is a declarative statistical visualization library for Python, based on Vega and Vega-Lite.
# - ggplot: ggplot is a plotting system for Python based on R's ggplot2 and the Grammar of Graphics. It is built for making profressional looking, plots quickly with minimal code.
# - Pygal: Pygal is a Python SVG charts creator that takes the hassle out of creating charts for the web.
# - Geoplotlib: Geoplotlib is a toolbox for creating maps and plotting geographical data.
# - Gleam: Gleam is inspired by R's Shiny package. It allows users to turn analysis scripts into interactive web apps without needing to know web development.
# - Missingno: Missingno provides a small toolset of flexible and easy-to-use missing data visualizations and utilities that allows you to get a quick visual summary of the completeness (or lack thereof) of your dataset.
# - Leather: Leather is the Python charting library for those who need charts now and don’t care if they’re perfect.
# - Wordcloud: Wordcloud is a tool for making beautiful word clouds.
# - Venn: Venn is a Python library for creating area-proportional two- and three-way Venn diagrams.

# %% [markdown]
# ## Grammer of Graphics for plotting in Python
# - Data: The data to be visualized.
# - Aesthetics: The visual properties of the data points, such as position, size, shape, color, and transparency.
# - Geometry: The geometric shapes used to represent the data points, such as bars, lines, and points.
# - Facets: The arrangement of the data into subsets, such as rows, columns, or panels.
# - Statistics: The statistical transformations applied to the data, such as aggregations, smoothing, and modeling.
# - Scales: The mapping of data values to visual properties, such as axis limits, tick marks, and color scales.
# - Themes: The overall visual appearance of the plot, such as colors, fonts, and gridlines.
# - Guides: The visual elements used to assist in reading the plot, such as legends, axes, and labels.
# - Interactivity: The interactive features of the plot, such as tooltips, zooming, and panning.
# - Annotations: The textual and graphical annotations used to highlight specific aspects of the plot.
# - Extensions: The additional features and plugins that enhance the plot, such as animations, sliders, and widgets.

# %% [markdown]
# ## Parts of a plot
# - Title: The title of the plot, which describes the main purpose or content of the visualization.
# - Axis Labels: The labels for the x and y axes, which describe the variables being plotted.
# - Tick Marks: The marks along the axes that indicate the scale or range of the data.
# - Gridlines: The lines that extend from the tick marks to assist in reading the plot.
# - Legend: The key that explains the colors, shapes, or sizes used to represent different groups or variables.
# - Data Points: The individual points, bars, lines, or other shapes that represent the data values.
# - Data Labels: The text or numbers that provide additional information about the data points.
# - Annotations: The additional text or shapes that highlight specific aspects of the plot.
# - Background: The overall appearance of the plot, including colors, fonts, and borders.

# %%
# import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# loading the dimond dataset
df = sns.load_dataset('diamonds')
# print the first 5 rows of the dataset
print(df.head())
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ## Explain each part of diamonds dataset:
# A data frame with 53,940 rows and 10 variables:
#
# - carat: Weight of the diamond (0.2--5.01)
# - cut: Quality of the cut (Fair, Good, Very Good, Premium, Ideal)
# - color: Diamond color, from D (best) to J (worst)
# - clarity: A measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# - depth: Total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
# - table: Width of top of diamond relative to widest point (43--95)
# - price: Price in US dollars (
# 18,823)
# - x: Length in mm (0--10.74)
# - y: Width in mm (0--58.9)
# - z: Depth in mm (0--31.8)

# %%
# ploting the line plot
sns.lineplot(x='carat', y='price', data=df, hue='cut', palette='Set1')
plt.title('Line Plot of Carat vs Price by Cut')
plt.xlabel('Carat')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
# scater plot
plt.scatter(df['carat'], df['price'])
plt.title('Carat vs Price Scatter Plot')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# %%
# bar plot
plt.bar(df['cut'].unique(), df.groupby('cut')['price'].mean())
plt.title('Average Price by Cut')
plt.xlabel('Cut')
plt.ylabel('Average Price')
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17876\3558449146.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   plt.bar(df['cut'].unique(), df.groupby('cut')['price'].mean())

# %% [markdown]
# ## Intermediate plots

# %%
# Histogram
plt.hist(df['price'], bins=30, color='blue', alpha=0.7)
plt.title('Price Distribution Histogram')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Box plot
plt.boxplot(df['price'])
plt.title('Price Box Plot')
plt.xlabel('Price')
plt.show()

# %%
# pie chart
plt.pie(df['cut'].value_counts(), labels=df['cut'].unique(), autopct='%1.1f%%', startangle=140)
plt.title('Cut Distribution Pie Chart')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# - Data Distribution
# - un-Balnace data

# %% [markdown]
# ## Advance Charts

# %%
# Heatmap of Correlation Matrix
correlation = df[['carat', 'depth', 'table', 'price', 'x', 'y', 'z']].corr()
plt.imshow(correlation, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.xticks(range(len(correlation)), correlation.columns, rotation=90)
plt.yticks(range(len(correlation)), correlation.columns)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %% [markdown]
# - just select the Numeric values
# -

# %%
# subplot
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs[0, 0].scatter(df['carat'], df['price'], color='blue', alpha=0.5)
axs[0, 0].set_title('Carat vs Price Scatter Plot')
axs[0, 0].set_xlabel('Carat')
axs[0, 0].set_ylabel('Price')
axs[0, 1].hist(df['price'], bins=30, color='green', alpha=0.7)
axs[0, 1].set_title('Price Distribution Histogram')
axs[0, 1].set_xlabel('Price')
axs[0, 1].set_ylabel('Frequency')
axs[1, 0].boxplot(df['price'])
axs[1, 0].set_title('Price Box Plot')
axs[1, 0].set_ylabel('Price')
axs[1, 1].pie(df['cut'].value_counts(), labels=df['cut'].unique(), autopct='%1.1f%%', startangle=140)
axs[1, 1].set_title('Cut Distribution Pie Chart')
axs[1, 1].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.show()

# %% [markdown]
# # Basic plot using seaborn

# %%
# seaborn scatter plot
sns.scatterplot(x='carat', y='price', data=df, hue='cut', palette='Set1')
plt.title('Seaborn Scatter Plot of Carat vs Price by Cut')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# %%
# seaborn line plot
sns.lineplot(x='carat', y='price', data=df, hue='cut', palette='Set1')
plt.title('Seaborn Line Plot of Carat vs Price by Cut')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# %%
# Seaborn Line Plot with Facets based on 'cut' column
g = sns.FacetGrid(df, col='cut', col_wrap=3, height=4)
g.map(sns.lineplot, 'carat', 'price')
g.add_legend()
plt.show()

# %% [markdown]
# ## Intermediate plots

# %%
# Box plot with seaborn
sns.boxplot(x='cut', y='price', data=df, palette='Set1')
plt.title('Seaborn Box Plot of Price by Cut')
plt.xlabel('Cut')
plt.ylabel('Price')
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17876\2769720488.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='cut', y='price', data=df, palette='Set1')

# %%
# Violin plot with seaborn
sns.violinplot(x='cut', y='price', data=df, palette='Set1')
plt.title('Seaborn Violin Plot of Price by Cut')
plt.xlabel('Cut')
plt.ylabel('Price')
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17876\599783156.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='cut', y='price', data=df, palette='Set1')

# %%
# count plot with seaborn
sns.countplot(x='cut', data=df, palette='Set1')
plt.title('Count Plot of Cut')
plt.xlabel('Cut')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_17876\3234022352.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='cut', data=df, palette='Set1')

# %%
# Pairplot with seaborn
sns.pairplot(df, hue='cut', palette='Set1')
plt.title('Pairplot of Diamonds Dataset')
plt.show()

# %%
# facet grid with seaborn
g = sns.FacetGrid(df, col='cut', row='color', margin_titles=True)
g.map_dataframe(sns.scatterplot, x='carat', y='price')
g.set_axis_labels('Carat', 'Price')
g.set_titles(col_template='{col_name}', row_template='{row_name}')
g.add_legend()
plt.show()

# %% [markdown]
# ## Advance Seaborn Plot

# %% [markdown]
# ### Plot with report ready visualization

# %%
# setting the style of seaborn
sns.set_style('whitegrid') # whitegrid, darkgrid, white, dark, ticks
sns.set_palette('Set1')
sns.set_context('talk') # paper, notebook, talk, poster
# Example plot with the new style
plt.figure(figsize=(8, 6))
sns.scatterplot(x='carat', y='price', data=df, hue='cut')
plt.title('Seaborn Scatter Plot with Custom Style')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# %%
# creating a custom color palette
custom_palette = sns.color_palette("husl", 8)  # 8 colors in the palette
sns.set_palette(custom_palette)
# Example plot with the custom color palette
plt.figure(figsize=(10, 8))
sns.scatterplot(x='carat', y='price', data=df, hue='cut')
plt.title('Seaborn Scatter Plot with Custom Color Palette')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# %%
# removing the top and right spines of the plot
sns.set_style('whitegrid')
sns.set_context('notebook')
plt.figure(figsize=(10, 6))
sns.barplot(x='carat', y='price', data=df, hue='cut') # using barplot for demonstration
plt.title('Seaborn Scatter Plot with Custom Style')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %%
# customizing the legend
plt.figure(figsize=(10, 6))
sns.scatterplot(x='carat', y='price', data=df, hue='cut', palette='Set1')
plt.title('Seaborn Scatter Plot with Custom Legend')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.legend(title='Cut', loc='upper right', fontsize='small', title_fontsize='medium')
plt.show()

# %%
# facet grid scatter plot with hue
g = sns.FacetGrid(df, col='cut', hue='color', palette='Set1', height=4, aspect=1.2)
g.map(sns.scatterplot, 'carat', 'price')
g.add_legend()
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Facet Grid Scatter Plot of Carat vs Price by Cut and Color')
plt.show()

# %%
# Adjusting the y-axis plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='carat', y='price', data=df, hue='cut', palette='Set1')
plt.title('Seaborn Scatter Plot with Adjusted Y-axis')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.ylim(0, 20000)  # Adjusting the y-axis limit
plt.gca().set_ylim(0, 20000)  # Set y-axis limit to 0-20000
plt.show()

# %%
# Saving the plot to a file
plt.figure(figsize=(10, 6))
sns.scatterplot(x='carat', y='price', data=df, hue='cut', palette='Set1')
plt.title('Seaborn Scatter Plot with Custom Style')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.savefig('seaborn_scatter_plot.svg', dpi=300, bbox_inches='tight')  # Save the plot as a PNG file
plt.show()

# %%
# List of all available colors palettes in seaborn
print(sns.palettes.SEABORN_PALETTES.keys())
# Out:
# dict_keys(['deep', 'deep6', 'muted', 'muted6', 'pastel', 'pastel6', 'bright', 'bright6', 'dark', 'dark6', 'colorblind', 'colorblind6'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to display all available Seaborn color palettes
def display_palettes():
    palette_names = sorted(sns.palettes.SEABORN_PALETTES)
    n = len(palette_names)
    
    # Create subplots
    fig, axes = plt.subplots(nrows=n, figsize=(8, 2 * n))
    
    for ax, palette_name in zip(axes, palette_names):
        colors = sns.color_palette(palette_name)
        for i, color in enumerate(colors):
            ax.add_patch(plt.Rectangle((i, 0), 1, 1, color=color))
        ax.set_xlim(0, len(colors))
        ax.set_ylim(0, 1)
        ax.set_title(palette_name, fontsize=10, pad=10)
        ax.axis('off')
    
    plt.tight_layout()
    plt.show()

display_palettes()
